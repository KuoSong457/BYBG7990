# %%
import pandas as pd
import xlrd 
import matplotlib.pyplot as plt

# %%
#open excel file
filename='1398.xlsx'
wb=xlrd.open_workbook(filename) 

sheet=wb.sheet_by_index(0)

# %%
#sheet.col_values(6)

# %%
#determine dimension of sheet
sheet.nrows
# Out:
# 1234

# %%
sheet.ncols
# Out:
# 7

# %%
data=[]
[data for c in range (sheet.ncols)]
for r in range (1,sheet.nrows):
         if sheet.cell_value(r,c) != 'Null':
             data.append(sheet.cell_value(r,c))

# %%
type(sheet.cell_value(1233,1) )
# Out:
# str

# %%
print(sheet.cell_value(1233,1))
# Out:
# none

# %%
df.isna()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# 5     False  False  False  False  False      False   False
# 6     False  False  False  False  False      False   False
# 7     False  False  False  False  False      False   False
# 8     False  False  False  False  False      False   False
# 9     False  False  False  False  False      False   False
# 10    False  False  False  False  False      False   False
# 11    False  False  False  False  False      False   False
# 12    False  False  False  False  False      False   False
# 13    False  False  False  False  False      False   False
# 14    False  False  False  False  False      False   False
# ...

# %%
len(data)
# Out:
# 1233

# %%
#get cell values of old sheet
data=[[sheet.cell_value(r,c) 
           for c in range (sheet.ncols)] 
          for r in range (1,sheet.nrows) ]

#if not sheet.cell_value(r,c).isdigit():
#    print(r)

           
df=pd.DataFrame(data,columns=['Date', 'Open', 'High', 'Low','Close','Adj Close','Volume'])

# %%
df.isna()
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# 5     False  False  False  False  False      False   False
# 6     False  False  False  False  False      False   False
# 7     False  False  False  False  False      False   False
# 8     False  False  False  False  False      False   False
# 9     False  False  False  False  False      False   False
# 10    False  False  False  False  False      False   False
# 11    False  False  False  False  False      False   False
# 12    False  False  False  False  False      False   False
# 13    False  False  False  False  False      False   False
# 14    False  False  False  False  False      False   False
# ...

# %%
for c in range (sheet.ncols):
     for r in range (1,sheet.nrows):
            a=df.iloc[r]
            if  isinstance(a,str):
            
                print(r)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-9e58aee66f0a> in <module>
#       1 for c in range (sheet.ncols):
#       2      for r in range (1,sheet.nrows):
# ----> 3             a=df.iloc[r]
#       4             if  isinstance(a,str):
#       5
#
# E:\anaconda\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# E:\anaconda\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2228
#    2229             # validate the location
# -> 2230             self._validate_integer(key, axis)
#    2231
#    2232             return self._get_loc(key, axis=axis)
#
# ...

# %%
df.iloc[2,3]
# Out:
# 5.44

# %%
pd.isnull(df)
# Out:
#        Date   Open   High    Low  Close  Adj Close  Volume
# 0     False  False  False  False  False      False   False
# 1     False  False  False  False  False      False   False
# 2     False  False  False  False  False      False   False
# 3     False  False  False  False  False      False   False
# 4     False  False  False  False  False      False   False
# 5     False  False  False  False  False      False   False
# 6     False  False  False  False  False      False   False
# 7     False  False  False  False  False      False   False
# 8     False  False  False  False  False      False   False
# 9     False  False  False  False  False      False   False
# 10    False  False  False  False  False      False   False
# 11    False  False  False  False  False      False   False
# 12    False  False  False  False  False      False   False
# 13    False  False  False  False  False      False   False
# 14    False  False  False  False  False      False   False
# ...

# %%
df
# Out:
#          Date  Open  High   Low Close Adj Close       Volume
# 0     42033.0  5.61  5.65  5.55   5.6   4.28608  2.90652e+08
# 1     42034.0  5.61  5.65  5.55  5.58   4.27077   2.0777e+08
# 2     42037.0  5.51  5.53  5.44   5.5   4.20954  2.95444e+08
# 3     42038.0   5.5  5.59  5.46  5.58   4.27077  1.65049e+08
# 4     42039.0  5.59  5.63  5.55  5.57   4.26312   2.3753e+08
# 5     42040.0  5.74  5.75  5.63  5.67   4.33966  4.31823e+08
# 6     42041.0  5.64  5.67  5.53  5.61   4.29373  2.57901e+08
# 7     42044.0  5.53  5.57   5.5  5.54   4.24016  2.89347e+08
# 8     42045.0   5.5  5.59  5.49  5.56   4.25547  1.65379e+08
# 9     42046.0  5.53  5.59  5.48  5.51    4.2172  2.40005e+08
# 10    42047.0  5.56   5.6  5.49  5.58   4.27077  2.06447e+08
# 11    42048.0  5.61  5.67   5.6  5.65   4.32435  1.97146e+08
# 12    42051.0  5.69  5.69  5.64  5.66     4.332  1.02911e+08
# 13    42052.0  5.63   5.7  5.63  5.68   4.34731  1.26763e+08
# ...

# %%
for r in (1,sheet.nrows):
    if df.isna().any(axis=1) =True:
        print(r)
# Out:
#   File "<ipython-input-50-73f4a67b0b28>", line 2
#     if df.isna().any(axis=1) =True:
#                              ^
# SyntaxError: invalid syntax

# %%
df[df.isna().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
df.isna().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1203    False
# 1204    False
# 1205    False
# 1206    False
# 1207    False
# 1208    False
# 1209    False
# 1210    False
# 1211    False
# 1212    False
# 1213    False
# 1214    False
# 1215    False
# 1216    False
# 1217    False
# 1218    False
# 1219    False
# 1220    False
# 1221    False
# 1222    False
# 1223    False
# 1224    False
# 1225    False
# 1226    False
# 1227    False
# 1228    False
# 1229    False
# 1230    False
# 1231    False
# 1232    False
# ...

# %%
df[df.Close.isna()]

# %%
df.dropna()

# %%
# working with an Excel date
wb.datemode
# Out:
# 0

# %%
time=[]
def datetime(i):
    cell_value=sheet.cell_value(i,0)
    date = xlrd.xldate.xldate_as_datetime(cell_value, wb.datemode)
    #print(date)
    time.append(date)

for i in range (1,sheet.nrows):
    datetime(i)

# %%
#insert new date column
df.insert(0,'DATE',time)

# %%
#delete old dare column
df.drop(['Date'], axis=1,inplace=True)

# %%
df
# Out:
#            DATE  Open  High   Low Close Adj Close       Volume
# 0    2015-01-29  5.61  5.65  5.55   5.6   4.28608  2.90652e+08
# 1    2015-01-30  5.61  5.65  5.55  5.58   4.27077   2.0777e+08
# 2    2015-02-02  5.51  5.53  5.44   5.5   4.20954  2.95444e+08
# 3    2015-02-03   5.5  5.59  5.46  5.58   4.27077  1.65049e+08
# 4    2015-02-04  5.59  5.63  5.55  5.57   4.26312   2.3753e+08
# 5    2015-02-05  5.74  5.75  5.63  5.67   4.33966  4.31823e+08
# 6    2015-02-06  5.64  5.67  5.53  5.61   4.29373  2.57901e+08
# 7    2015-02-09  5.53  5.57   5.5  5.54   4.24016  2.89347e+08
# 8    2015-02-10   5.5  5.59  5.49  5.56   4.25547  1.65379e+08
# 9    2015-02-11  5.53  5.59  5.48  5.51    4.2172  2.40005e+08
# 10   2015-02-12  5.56   5.6  5.49  5.58   4.27077  2.06447e+08
# 11   2015-02-13  5.61  5.67   5.6  5.65   4.32435  1.97146e+08
# 12   2015-02-16  5.69  5.69  5.64  5.66     4.332  1.02911e+08
# 13   2015-02-17  5.63   5.7  5.63  5.68   4.34731  1.26763e+08
# ...

# %%
#df = df.dropnul(how='any',axis=0)

# %%
df
# Out:
#            DATE  Open  High   Low Close Adj Close       Volume
# 0    2015-01-29  5.61  5.65  5.55   5.6   4.28608  2.90652e+08
# 1    2015-01-30  5.61  5.65  5.55  5.58   4.27077   2.0777e+08
# 2    2015-02-02  5.51  5.53  5.44   5.5   4.20954  2.95444e+08
# 3    2015-02-03   5.5  5.59  5.46  5.58   4.27077  1.65049e+08
# 4    2015-02-04  5.59  5.63  5.55  5.57   4.26312   2.3753e+08
# 5    2015-02-05  5.74  5.75  5.63  5.67   4.33966  4.31823e+08
# 6    2015-02-06  5.64  5.67  5.53  5.61   4.29373  2.57901e+08
# 7    2015-02-09  5.53  5.57   5.5  5.54   4.24016  2.89347e+08
# 8    2015-02-10   5.5  5.59  5.49  5.56   4.25547  1.65379e+08
# 9    2015-02-11  5.53  5.59  5.48  5.51    4.2172  2.40005e+08
# 10   2015-02-12  5.56   5.6  5.49  5.58   4.27077  2.06447e+08
# 11   2015-02-13  5.61  5.67   5.6  5.65   4.32435  1.97146e+08
# 12   2015-02-16  5.69  5.69  5.64  5.66     4.332  1.02911e+08
# 13   2015-02-17  5.63   5.7  5.63  5.68   4.34731  1.26763e+08
# ...

# %%
len(dr)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9c9935fdc204> in <module>
# ----> 1 len(dr)
#
# NameError: name 'dr' is not defined

# %%
df["Daily Returns"] = df["Adj Close"].pct_change()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-1a682bf14843> in <module>
# ----> 1 df["Daily Returns"] = df["Adj Close"].pct_change()
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in pct_change(self, periods, fill_method, limit, freq, **kwargs)
#    9957
#    9958         rs = (data.div(data.shift(periods=periods, freq=freq, axis=axis,
# -> 9959                                   **kwargs)) - 1)
#    9960         rs = rs.reindex_like(data)
#    9961         if freq is None:
#
# E:\anaconda\lib\site-packages\pandas\core\ops.py in flex_wrapper(self, other, level, fill_value, axis)
#    1868             self._get_axis_number(axis)
#    1869         if isinstance(other, ABCSeries):
# -> 1870             return self._binop(other, op, level=level, fill_value=fill_value)
#    1871         elif isinstance(other, (np.ndarray, list, tuple)):
# ...

# %%
plt.hist(df['Daily Returns'], bins=10)
np.warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Daily Returns'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-9f900197b7d0> in <module>
# ----> 1 plt.hist(df['Daily Returns'], bins=10)
# ...
